# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('HR.jpg')
img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img = cv2.resize(img,(400,400))

# %%
plt.imshow(img)

# %%
har = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
faces = har.detectMultiScale(img,1.3,5)

# %%
faces
# Out:
# array([[124,  63, 163, 163]], dtype=int32)

# %%
plt.imshow(img[63:(63+163),124:(124+163)])

# %%
img2 = cv2.imread('AK.jpg')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
img2 = cv2.resize(img2,(400,400))
plt.imshow(img2)

# %%
faces2 = har.detectMultiScale(img2,1.3,5)

# %%
faces2
# Out:
# array([[194,  72, 116, 116]], dtype=int32)

# %%
plt.imshow(img2[72:(72+116),194:(194+116)])

# %%
temp = img

# %%
temp[63:(63+163),124:(124+163)] = img2[72:(72+116),194:(194+116)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-97-c2e0426446d1> in <module>
# ----> 1 temp[63:(63+163),124:(124+163)] = img2[72:(72+116),194:(194+116)]
#
# ValueError: could not broadcast input array from shape (116,116) into shape (163,163)

# %%
# import numpy as np
# temp = np.zeros((163,163))

# %%
temp[72:(72+116),194:(194+116)] = img2[72:(72+116),194:(194+116)]

# %%
plt.imshow(temp)

# %%
plt.imshow(img2[72:(72+116),210:(190+100)])
